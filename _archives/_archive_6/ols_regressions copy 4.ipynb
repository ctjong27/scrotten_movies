# %%
import pandas as pd

# Load data
df = pd.read_csv('../data/tv_export_data.csv')

# Remove undetermined gender
df = df[df['profile_gender'] != 'Undetermined']

# Filter by 'Acting' job
df = df[df['known_for_department'] == 'Acting']

# Create a new column to combine race and gender
df['race_gender'] = df['profile_race'] + "_" + df['profile_gender']

# Calculate total episode count for each race and gender combination
total_episode_count = df.groupby('race_gender')['episode_count'].sum().reset_index(name='total_episode_count')

# Calculate total distinct individuals for each race and gender combination
total_distinct_individuals = df.groupby('race_gender')['cast_id'].nunique().reset_index(name='total_distinct_individuals')

# Merge two dataframes
trends = pd.merge(total_episode_count, total_distinct_individuals, on='race_gender')

# Show the trends
print(trends)
# Out:
#                race_gender  total_episode_count  total_distinct_individuals
# 0           _total__Female               981164                       19755
# 1             _total__Male              1988178                       36534
# 2             asian_Female                48132                        1705
# 3               asian_Male                94787                        2715
# 4             black_Female                47874                        1197
# 5               black_Male               188648                        3929
# 6            indian_Female                 5893                         104
# 7              indian_Male                10667                         274
# 8   latino hispanic_Female                71761                        2001
# 9     latino hispanic_Male               234245                        3847
# 10   middle eastern_Female                 5156                         193
# 11     middle eastern_Male               132649                        3179
# 12            white_Female               802348                       14555
# 13              white_Male              1327182                       22590

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Load data
df = pd.read_csv('../data/tv_export_data.csv')

# Remove undetermined gender
df = df[df['profile_gender'] != 'Undetermined']

# Filter by 'Acting' job
df = df[df['known_for_department'] == 'Acting']

# Convert air_date to datetime and extract year
df['season_air_date'] = pd.to_datetime(df['season_air_date'])
df['year'] = df['season_air_date'].dt.year

# Create a new column to combine race and gender
df['race_gender'] = df['profile_race'] + "_" + df['profile_gender']

# Group data by year and race/gender, calculating total episode count and distinct individuals
grouped_df = df.groupby(['year', 'race_gender']).agg({'episode_count': 'sum', 'cast_id': 'nunique'}).reset_index()
grouped_df.rename(columns={'cast_id': 'distinct_individuals'}, inplace=True)

# Loop over each race/gender combination and run a regression for each
for race_gender in grouped_df['race_gender'].unique():
    subset = grouped_df[grouped_df['race_gender'] == race_gender]
    model = smf.ols(formula='episode_count ~ year', data=subset).fit()
    print(f"Regression results for {race_gender}:")
    print(model.summary())
    print("\n")

# Note: This will print the regression results for each race/gender combination separately.
# Each summary includes the R-squared value (which shows the proportion of the variance for the dependent variable that's explained by the independent variable), the coefficients, and other statistics.
# Out:
# Regression results for _total__Female:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          episode_count   R-squared:                       0.548
# Model:                            OLS   Adj. R-squared:                  0.540
# Method:                 Least Squares   F-statistic:                     75.10
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           2.79e-12
# Time:                        11:46:35   Log-Likelihood:                -649.80
# No. Observations:                  64   AIC:                             1304.
# Df Residuals:                      62   BIC:                             1308.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -7.219e+05    8.5e+04     -8.488      0.000   -8.92e+05   -5.52e+05
# year         370.0461     42.702      8.666      0.000     284.687     455.405
# ==============================================================================
# Omnibus:                        6.330   Durbin-Watson:                   0.750
# Prob(Omnibus):                  0.042   Jarque-Bera (JB):                9.092
# Skew:                           0.225   Prob(JB):                       0.0106
# Kurtosis:                       4.791   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for _total__Male:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          episode_count   R-squared:                       0.527
# Model:                            OLS   Adj. R-squared:                  0.519
# Method:                 Least Squares   F-statistic:                     68.99
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           1.17e-11
# Time:                        11:46:35   Log-Likelihood:                -685.05
# No. Observations:                  64   AIC:                             1374.
# Df Residuals:                      62   BIC:                             1378.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.195e+06   1.48e+05     -8.098      0.000   -1.49e+06      -9e+05
# year         615.3023     74.077      8.306      0.000     467.224     763.380
# ==============================================================================
# Omnibus:                        6.726   Durbin-Watson:                   0.582
# Prob(Omnibus):                  0.035   Jarque-Bera (JB):               10.912
# Skew:                          -0.164   Prob(JB):                      0.00427
# Kurtosis:                       4.996   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for asian_Female:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          episode_count   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     262.5
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           5.80e-24
# Time:                        11:46:35   Log-Likelihood:                -457.95
# No. Observations:                  64   AIC:                             919.9
# Df Residuals:                      62   BIC:                             924.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6.801e+04   4244.138    -16.025      0.000   -7.65e+04   -5.95e+04
# year          34.5290      2.131     16.203      0.000      30.269      38.789
# ==============================================================================
# Omnibus:                        6.471   Durbin-Watson:                   0.542
# Prob(Omnibus):                  0.039   Jarque-Bera (JB):                8.097
# Skew:                          -0.339   Prob(JB):                       0.0174
# Kurtosis:                       4.605   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for asian_Male:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          episode_count   R-squared:                       0.672
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     126.8
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           1.25e-16
# Time:                        11:46:35   Log-Likelihood:                -490.52
# No. Observations:                  64   AIC:                             985.0
# Df Residuals:                      62   BIC:                             989.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -7.804e+04   7060.650    -11.053      0.000   -9.22e+04   -6.39e+04
# year          39.9208      3.545     11.260      0.000      32.834      47.008
# ==============================================================================
# Omnibus:                        7.056   Durbin-Watson:                   0.792
# Prob(Omnibus):                  0.029   Jarque-Bera (JB):               10.451
# Skew:                          -0.285   Prob(JB):                      0.00538
# Kurtosis:                       4.896   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for black_Female:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          episode_count   R-squared:                       0.676
# Model:                            OLS   Adj. R-squared:                  0.671
# Method:                 Least Squares   F-statistic:                     125.5
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           2.46e-16
# Time:                        11:46:35   Log-Likelihood:                -451.50
# No. Observations:                  62   AIC:                             907.0
# Df Residuals:                      60   BIC:                             911.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -5.572e+04   5042.567    -11.051      0.000   -6.58e+04   -4.56e+04
# year          28.3455      2.531     11.201      0.000      23.283      33.408
# ==============================================================================
# Omnibus:                        4.681   Durbin-Watson:                   0.896
# Prob(Omnibus):                  0.096   Jarque-Bera (JB):                5.920
# Skew:                          -0.012   Prob(JB):                       0.0518
# Kurtosis:                       4.514   Cond. No.                     2.21e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.21e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for black_Male:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          episode_count   R-squared:                       0.753
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     189.4
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           1.64e-20
# Time:                        11:46:35   Log-Likelihood:                -524.85
# No. Observations:                  64   AIC:                             1054.
# Df Residuals:                      62   BIC:                             1058.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.632e+05   1.21e+04    -13.521      0.000   -1.87e+05   -1.39e+05
# year          83.4316      6.062     13.764      0.000      71.315      95.549
# ==============================================================================
# Omnibus:                       21.297   Durbin-Watson:                   0.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               61.790
# Skew:                          -0.865   Prob(JB):                     3.82e-14
# Kurtosis:                       7.492   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for indian_Male:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          episode_count   R-squared:                       0.347
# Model:                            OLS   Adj. R-squared:                  0.336
# Method:                 Least Squares   F-statistic:                     32.92
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           3.08e-07
# Time:                        11:46:35   Log-Likelihood:                -383.90
# No. Observations:                  64   AIC:                             771.8
# Df Residuals:                      62   BIC:                             776.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -7489.9731   1334.421     -5.613      0.000   -1.02e+04   -4822.504
# year           3.8442      0.670      5.737      0.000       2.505       5.184
# ==============================================================================
# Omnibus:                       10.114   Durbin-Watson:                   0.981
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):                3.758
# Skew:                           0.280   Prob(JB):                        0.153
# Kurtosis:                       1.954   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for latino hispanic_Female:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          episode_count   R-squared:                       0.724
# Model:                            OLS   Adj. R-squared:                  0.719
# Method:                 Least Squares   F-statistic:                     162.3
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           5.77e-19
# Time:                        11:46:35   Log-Likelihood:                -492.43
# No. Observations:                  64   AIC:                             988.9
# Df Residuals:                      62   BIC:                             993.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -9.155e+04   7274.080    -12.586      0.000   -1.06e+05    -7.7e+04
# year          46.5275      3.652     12.739      0.000      39.226      53.829
# ==============================================================================
# Omnibus:                        5.456   Durbin-Watson:                   0.625
# Prob(Omnibus):                  0.065   Jarque-Bera (JB):                4.615
# Skew:                           0.517   Prob(JB):                       0.0995
# Kurtosis:                       3.812   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for latino hispanic_Male:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          episode_count   R-squared:                       0.500
# Model:                            OLS   Adj. R-squared:                  0.491
# Method:                 Least Squares   F-statistic:                     61.89
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           6.74e-11
# Time:                        11:46:35   Log-Likelihood:                -546.73
# No. Observations:                  64   AIC:                             1097.
# Df Residuals:                      62   BIC:                             1102.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.301e+05    1.7e+04     -7.655      0.000   -1.64e+05   -9.61e+04
# year          67.1221      8.532      7.867      0.000      50.066      84.178
# ==============================================================================
# Omnibus:                        7.062   Durbin-Watson:                   0.627
# Prob(Omnibus):                  0.029   Jarque-Bera (JB):                9.015
# Skew:                          -0.382   Prob(JB):                       0.0110
# Kurtosis:                       4.673   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for middle eastern_Male:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          episode_count   R-squared:                       0.425
# Model:                            OLS   Adj. R-squared:                  0.416
# Method:                 Least Squares   F-statistic:                     45.88
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           5.29e-09
# Time:                        11:46:35   Log-Likelihood:                -510.54
# No. Observations:                  64   AIC:                             1025.
# Df Residuals:                      62   BIC:                             1029.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6.335e+04   9653.743     -6.562      0.000   -8.26e+04   -4.41e+04
# year          32.8334      4.847      6.774      0.000      23.144      42.523
# ==============================================================================
# Omnibus:                        6.072   Durbin-Watson:                   0.758
# Prob(Omnibus):                  0.048   Jarque-Bera (JB):                9.253
# Skew:                          -0.121   Prob(JB):                      0.00979
# Kurtosis:                       4.847   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for white_Female:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          episode_count   R-squared:                       0.425
# Model:                            OLS   Adj. R-squared:                  0.415
# Method:                 Least Squares   F-statistic:                     45.77
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           5.47e-09
# Time:                        11:46:35   Log-Likelihood:                -641.60
# No. Observations:                  64   AIC:                             1287.
# Df Residuals:                      62   BIC:                             1292.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -4.939e+05   7.48e+04     -6.600      0.000   -6.43e+05   -3.44e+05
# year         254.1725     37.571      6.765      0.000     179.069     329.276
# ==============================================================================
# Omnibus:                        7.944   Durbin-Watson:                   0.716
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                9.059
# Skew:                           0.522   Prob(JB):                       0.0108
# Kurtosis:                       4.519   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for white_Male:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          episode_count   R-squared:                       0.448
# Model:                            OLS   Adj. R-squared:                  0.439
# Method:                 Least Squares   F-statistic:                     50.31
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           1.49e-09
# Time:                        11:46:36   Log-Likelihood:                -665.67
# No. Observations:                  64   AIC:                             1335.
# Df Residuals:                      62   BIC:                             1340.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -7.525e+05   1.09e+05     -6.904      0.000    -9.7e+05   -5.35e+05
# year         388.1502     54.725      7.093      0.000     278.756     497.545
# ==============================================================================
# Omnibus:                        3.376   Durbin-Watson:                   0.523
# Prob(Omnibus):                  0.185   Jarque-Bera (JB):                3.283
# Skew:                           0.072   Prob(JB):                        0.194
# Kurtosis:                       4.100   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for middle eastern_Female:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          episode_count   R-squared:                       0.586
# Model:                            OLS   Adj. R-squared:                  0.579
# Method:                 Least Squares   F-statistic:                     77.94
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           3.98e-12
# Time:                        11:46:36   Log-Likelihood:                -305.77
# No. Observations:                  57   AIC:                             615.5
# Df Residuals:                      55   BIC:                             619.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6722.8570    771.607     -8.713      0.000   -8269.193   -5176.521
# year           3.4165      0.387      8.829      0.000       2.641       4.192
# ==============================================================================
# Omnibus:                        7.518   Durbin-Watson:                   0.853
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):                6.893
# Skew:                           0.664   Prob(JB):                       0.0319
# Kurtosis:                       4.067   Cond. No.                     2.21e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.21e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for indian_Female:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          episode_count   R-squared:                       0.185
# Model:                            OLS   Adj. R-squared:                  0.170
# Method:                 Least Squares   F-statistic:                     12.23
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           0.000948
# Time:                        11:46:36   Log-Likelihood:                -346.29
# No. Observations:                  56   AIC:                             696.6
# Df Residuals:                      54   BIC:                             700.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6463.9140   1878.299     -3.441      0.001   -1.02e+04   -2698.152
# year           3.2927      0.941      3.497      0.001       1.405       5.180
# ==============================================================================
# Omnibus:                       10.043   Durbin-Watson:                   0.727
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):                6.300
# Skew:                           0.661   Prob(JB):                       0.0428
# Kurtosis:                       2.023   Cond. No.                     2.35e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.35e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Load data
df = pd.read_csv('../data/tv_export_data.csv')

# Remove undetermined gender
df = df[df['profile_gender'] != 'Undetermined']

# Filter by 'Acting' job
df = df[df['known_for_department'] == 'Acting']

# Convert air_date to datetime and extract year
df['season_air_date'] = pd.to_datetime(df['season_air_date'])
df['year'] = df['season_air_date'].dt.year

# Group data by year, race and gender, calculating total episode count
grouped_df = df.groupby(['year', 'profile_race', 'profile_gender']).agg({'episode_count': 'sum'}).reset_index()

# Calculate yearly total for each race
yearly_race_totals = grouped_df.groupby(['year', 'profile_race']).agg({'episode_count': 'sum'}).reset_index()

# Merge yearly race totals back to the grouped_df
grouped_df = pd.merge(grouped_df, yearly_race_totals, how='left', on=['year', 'profile_race'])

# Calculate percentage
grouped_df['percentage'] = grouped_df['episode_count_x'] / grouped_df['episode_count_y'] * 100

# Now for each subdemographic group (race_gender), calculate the yearly rate of change using regression
grouped_df['race_gender'] = grouped_df['profile_race'] + "_" + grouped_df['profile_gender']

# Loop over each race/gender combination and run a regression for each
for race_gender in grouped_df['race_gender'].unique():
    subset = grouped_df[grouped_df['race_gender'] == race_gender]
    model = smf.ols(formula='percentage ~ year', data=subset).fit()
    print(f"Regression results for {race_gender}:")
    print(model.summary())
    print("\n")
# Out:
# Regression results for _total__Female:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.419
# Model:                            OLS   Adj. R-squared:                  0.409
# Method:                 Least Squares   F-statistic:                     44.62
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           7.67e-09
# Time:                        11:50:52   Log-Likelihood:                -172.59
# No. Observations:                  64   AIC:                             349.2
# Df Residuals:                      62   BIC:                             353.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -297.0417     49.133     -6.046      0.000    -395.256    -198.827
# year           0.1648      0.025      6.680      0.000       0.115       0.214
# ==============================================================================
# Omnibus:                        1.424   Durbin-Watson:                   1.132
# Prob(Omnibus):                  0.491   Jarque-Bera (JB):                1.441
# Skew:                           0.330   Prob(JB):                        0.486
# Kurtosis:                       2.675   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for _total__Male:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.419
# Model:                            OLS   Adj. R-squared:                  0.409
# Method:                 Least Squares   F-statistic:                     44.62
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           7.67e-09
# Time:                        11:50:52   Log-Likelihood:                -172.59
# No. Observations:                  64   AIC:                             349.2
# Df Residuals:                      62   BIC:                             353.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    397.0417     49.133      8.081      0.000     298.827     495.256
# year          -0.1648      0.025     -6.680      0.000      -0.214      -0.115
# ==============================================================================
# Omnibus:                        1.424   Durbin-Watson:                   1.132
# Prob(Omnibus):                  0.491   Jarque-Bera (JB):                1.441
# Skew:                          -0.330   Prob(JB):                        0.486
# Kurtosis:                       2.675   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for asian_Female:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.794
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     238.5
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           6.33e-23
# Time:                        11:50:52   Log-Likelihood:                -210.11
# No. Observations:                  64   AIC:                             424.2
# Df Residuals:                      62   BIC:                             428.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1337.8244     88.312    -15.149      0.000   -1514.357   -1161.291
# year           0.6849      0.044     15.445      0.000       0.596       0.774
# ==============================================================================
# Omnibus:                        2.057   Durbin-Watson:                   0.688
# Prob(Omnibus):                  0.358   Jarque-Bera (JB):                1.828
# Skew:                           0.297   Prob(JB):                        0.401
# Kurtosis:                       2.424   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for asian_Male:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.794
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     238.5
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           6.33e-23
# Time:                        11:50:52   Log-Likelihood:                -210.11
# No. Observations:                  64   AIC:                             424.2
# Df Residuals:                      62   BIC:                             428.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1437.8244     88.312     16.281      0.000    1261.291    1614.357
# year          -0.6849      0.044    -15.445      0.000      -0.774      -0.596
# ==============================================================================
# Omnibus:                        2.057   Durbin-Watson:                   0.688
# Prob(Omnibus):                  0.358   Jarque-Bera (JB):                1.828
# Skew:                          -0.297   Prob(JB):                        0.401
# Kurtosis:                       2.424   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for black_Female:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.411
# Model:                            OLS   Adj. R-squared:                  0.401
# Method:                 Least Squares   F-statistic:                     41.80
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           2.02e-08
# Time:                        11:50:52   Log-Likelihood:                -185.23
# No. Observations:                  62   AIC:                             374.5
# Df Residuals:                      60   BIC:                             378.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -427.4590     68.782     -6.215      0.000    -565.044    -289.874
# year           0.2232      0.035      6.466      0.000       0.154       0.292
# ==============================================================================
# Omnibus:                       10.241   Durbin-Watson:                   1.635
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               11.986
# Skew:                           0.687   Prob(JB):                      0.00250
# Kurtosis:                       4.659   Cond. No.                     2.21e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.21e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for black_Male:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.461
# Model:                            OLS   Adj. R-squared:                  0.452
# Method:                 Least Squares   F-statistic:                     52.97
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           7.09e-10
# Time:                        11:50:52   Log-Likelihood:                -194.17
# No. Observations:                  64   AIC:                             392.3
# Df Residuals:                      62   BIC:                             396.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    584.3204     68.844      8.488      0.000     446.703     721.938
# year          -0.2516      0.035     -7.278      0.000      -0.321      -0.182
# ==============================================================================
# Omnibus:                       11.196   Durbin-Watson:                   1.490
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               13.768
# Skew:                          -0.716   Prob(JB):                      0.00102
# Kurtosis:                       4.765   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for indian_Male:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.153
# Model:                            OLS   Adj. R-squared:                  0.139
# Method:                 Least Squares   F-statistic:                     11.21
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):            0.00139
# Time:                        11:50:52   Log-Likelihood:                -282.96
# No. Observations:                  64   AIC:                             569.9
# Df Residuals:                      62   BIC:                             574.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    999.0578    275.641      3.624      0.001     448.060    1550.056
# year          -0.4633      0.138     -3.348      0.001      -0.740      -0.187
# ==============================================================================
# Omnibus:                        8.532   Durbin-Watson:                   0.874
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):                7.997
# Skew:                          -0.824   Prob(JB):                       0.0183
# Kurtosis:                       3.532   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for latino hispanic_Female:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.716
# Model:                            OLS   Adj. R-squared:                  0.711
# Method:                 Least Squares   F-statistic:                     156.3
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           1.34e-18
# Time:                        11:50:52   Log-Likelihood:                -205.73
# No. Observations:                  64   AIC:                             415.5
# Df Residuals:                      62   BIC:                             419.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1011.6430     82.469    -12.267      0.000   -1176.496    -846.790
# year           0.5177      0.041     12.501      0.000       0.435       0.600
# ==============================================================================
# Omnibus:                        4.778   Durbin-Watson:                   0.357
# Prob(Omnibus):                  0.092   Jarque-Bera (JB):                3.922
# Skew:                           0.498   Prob(JB):                        0.141
# Kurtosis:                       2.309   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for latino hispanic_Male:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.716
# Model:                            OLS   Adj. R-squared:                  0.711
# Method:                 Least Squares   F-statistic:                     156.3
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           1.34e-18
# Time:                        11:50:52   Log-Likelihood:                -205.73
# No. Observations:                  64   AIC:                             415.5
# Df Residuals:                      62   BIC:                             419.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1111.6430     82.469     13.480      0.000     946.790    1276.496
# year          -0.5177      0.041    -12.501      0.000      -0.600      -0.435
# ==============================================================================
# Omnibus:                        4.778   Durbin-Watson:                   0.357
# Prob(Omnibus):                  0.092   Jarque-Bera (JB):                3.922
# Skew:                          -0.498   Prob(JB):                        0.141
# Kurtosis:                       2.309   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for middle eastern_Male:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.473
# Model:                            OLS   Adj. R-squared:                  0.464
# Method:                 Least Squares   F-statistic:                     55.60
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           3.47e-10
# Time:                        11:50:52   Log-Likelihood:                -141.23
# No. Observations:                  64   AIC:                             286.5
# Df Residuals:                      62   BIC:                             290.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    321.1836     30.101     10.670      0.000     261.012     381.355
# year          -0.1127      0.015     -7.457      0.000      -0.143      -0.082
# ==============================================================================
# Omnibus:                       37.331   Durbin-Watson:                   1.071
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               96.733
# Skew:                          -1.829   Prob(JB):                     9.88e-22
# Kurtosis:                       7.785   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for white_Female:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.145
# Model:                            OLS   Adj. R-squared:                  0.132
# Method:                 Least Squares   F-statistic:                     10.54
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):            0.00188
# Time:                        11:50:52   Log-Likelihood:                -177.91
# No. Observations:                  64   AIC:                             359.8
# Df Residuals:                      62   BIC:                             364.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -136.9539     53.392     -2.565      0.013    -243.683     -30.225
# year           0.0870      0.027      3.247      0.002       0.033       0.141
# ==============================================================================
# Omnibus:                        1.294   Durbin-Watson:                   1.343
# Prob(Omnibus):                  0.524   Jarque-Bera (JB):                0.635
# Skew:                           0.067   Prob(JB):                        0.728
# Kurtosis:                       3.469   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for white_Male:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.145
# Model:                            OLS   Adj. R-squared:                  0.132
# Method:                 Least Squares   F-statistic:                     10.54
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):            0.00188
# Time:                        11:50:52   Log-Likelihood:                -177.91
# No. Observations:                  64   AIC:                             359.8
# Df Residuals:                      62   BIC:                             364.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    236.9539     53.392      4.438      0.000     130.225     343.683
# year          -0.0870      0.027     -3.247      0.002      -0.141      -0.033
# ==============================================================================
# Omnibus:                        1.294   Durbin-Watson:                   1.343
# Prob(Omnibus):                  0.524   Jarque-Bera (JB):                0.635
# Skew:                          -0.067   Prob(JB):                        0.728
# Kurtosis:                       3.469   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for middle eastern_Female:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.416
# Model:                            OLS   Adj. R-squared:                  0.406
# Method:                 Least Squares   F-statistic:                     39.24
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):           6.00e-08
# Time:                        11:50:52   Log-Likelihood:                -127.58
# No. Observations:                  57   AIC:                             259.2
# Df Residuals:                      55   BIC:                             263.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -208.4731     33.865     -6.156      0.000    -276.340    -140.606
# year           0.1064      0.017      6.265      0.000       0.072       0.140
# ==============================================================================
# Omnibus:                       31.524   Durbin-Watson:                   1.105
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               68.048
# Skew:                           1.724   Prob(JB):                     1.67e-15
# Kurtosis:                       7.095   Cond. No.                     2.21e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.21e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression results for indian_Female:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     3.239
# Date:                Mon, 31 Jul 2023   Prob (F-statistic):             0.0775
# Time:                        11:50:52   Log-Likelihood:                -249.23
# No. Observations:                  56   AIC:                             502.5
# Df Residuals:                      54   BIC:                             506.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -570.3868    331.950     -1.718      0.091   -1235.906      95.132
# year           0.2995      0.166      1.800      0.077      -0.034       0.633
# ==============================================================================
# Omnibus:                        3.641   Durbin-Watson:                   0.843
# Prob(Omnibus):                  0.162   Jarque-Bera (JB):                3.432
# Skew:                           0.597   Prob(JB):                        0.180
# Kurtosis:                       2.791   Cond. No.                     2.35e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.35e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
