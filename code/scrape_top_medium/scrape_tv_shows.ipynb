# %%
import requests
import csv
import os

# Variables
api_key = '4ea37a8158ca566deb7455166dc1edda'
num_top_shows = 25  # Desired number of top shows here

# Create data directory if it does not exist
os.makedirs('./data', exist_ok=True)

# Prepare data for CSV
csv_data = []

for year in range(1970, 2021):
    page = 1
    shows_filtered = []
    
    while len(shows_filtered) < num_top_shows:
        url = f"https://api.themoviedb.org/3/discover/tv?api_key={api_key}&language=en-US&sort_by=popularity.desc&first_air_date_year={year}&page={page}"

        response = requests.get(url)

        if response.status_code == 200:
            data = response.json()
            shows = data['results']
            
            # Filter shows based on original_language
            shows_filtered += [show for show in shows if show['original_language'] == 'en']

            page += 1
        else:
            print("Error:", response.status_code)
            break

    for i, show in enumerate(shows_filtered[:num_top_shows], start=1):
        print(show)
        csv_data.append([year, show['id'], show['name'], show['genre_ids'], show['first_air_date'], show['origin_country'], show['vote_average'], show['popularity']])

# Write to CSV
with open(f'./data/tv_shows_top_{num_top_shows}_yearly.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(["Year", "Rank", "Show Name", "First Air Date", "Rating", "Overview"])  # Write header
    writer.writerows(csv_data)  # Write data
# Out:
# {'backdrop_path': '/k6wPlUYtoxpQB9M63I6z2oSHLuz.jpg', 'first_air_date': '1970-01-05', 'genre_ids': [10766], 'id': 879, 'name': 'All My Children', 'origin_country': ['US'], 'original_language': 'en', 'original_name': 'All My Children', 'overview': 'All My Children is an American television soap opera that aired on ABC for 41 years, from January 5, 1970 to September 23, 2011, and on The Online Network since April 29, 2013 via Hulu, Hulu Plus, and iTunes. Created by Agnes Nixon, All My Children is set in Pine Valley, Pennsylvania, a fictitious suburb of Philadelphia which is modeled on the actual Philadelphia suburb of Rosemont.', 'popularity': 66.911, 'poster_path': '/4zYDW6wunTm5gm8vo4dfhpvkT0w.jpg', 'vote_average': 6, 'vote_count': 16}
# ...
